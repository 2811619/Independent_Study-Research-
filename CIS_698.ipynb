# %% [markdown]
# <a href="https://colab.research.google.com/github/2811619/Independent_Study_Research/blob/main/CIS_698.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import datetime as dt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataframe = pd.concat(pd.read_excel(r"/content/drive/MyDrive/Raw data_Content(2010-2020).xlsx",
                       sheet_name=['2010_ALL', '2011_ALL', '2012_ALL', '2013_ALL', '2014_ALL', '2015_ALL', '2016_ALL', '2017_ALL', '2018_ALL', '2019_ALL', '2020_ALL']))

# %%
dataframe
# Out:
#                                                   Form & File  \
# 2010_ALL 0                         10-K (Annual report) EX-13
#          1    20-F (Annual report - foreign issuer) EX-15.(B)
# 2011_ALL 0                         10-K (Annual report) EX-13
#          1                               10-K (Annual report)
#          2                               10-K (Annual report)
# ...                                                       ...
# 2020_ALL 325            20-F (Annual report - foreign issuer)
#          326            20-F (Annual report - foreign issuer)
#          327               40-F (Registration statement) EX-1
#          328             40-F (Registration statement) EX-1.1
#          329            40-F (Registration statement) EX-99.1
#
#              Filed\n(YYYY-MM-DD) Reporting for\n(YYYY-MM-DD)  \
# 2010_ALL 0            2010-03-01                  2010-01-01
#          1            2010-02-22                  2009-12-31
# ...

# %%
#Checking the null values
count = dataframe.isnull().sum()
print(count)
# Out:
# Form & File                      0
# Filed\n(YYYY-MM-DD)              0
# Reporting for\n(YYYY-MM-DD)      1
# Filing entity/person             0
# SIC                              0
# CIK\n(full 10 digit)             0
# Located                         14
# Incorporated                   491
# Conflict mineral(s)              4
# *adverse*                        0
# *expense*,*cost*                 0
# *reputation*                     0
# *difficult*                      0
# *support*                        0
# *commit*                         0
# *effort*                       283
# *compliance*, *comply*         283
# dtype: int64

# %%
dataframe = dataframe.dropna()
dataframe.isnull().sum()
# Out:
# Form & File                    0
# Filed\n(YYYY-MM-DD)            0
# Reporting for\n(YYYY-MM-DD)    0
# Filing entity/person           0
# SIC                            0
# CIK\n(full 10 digit)           0
# Located                        0
# Incorporated                   0
# Conflict mineral(s)            0
# *adverse*                      0
# *expense*,*cost*               0
# *reputation*                   0
# *difficult*                    0
# *support*                      0
# *commit*                       0
# *effort*                       0
# *compliance*, *comply*         0
# dtype: int64

# %%
dataframe
# Out:
#                                                  Form & File  \
# 2010_ALL 0                        10-K (Annual report) EX-13
#          1   20-F (Annual report - foreign issuer) EX-15.(B)
# 2011_ALL 0                        10-K (Annual report) EX-13
#          1                              10-K (Annual report)
#          2                              10-K (Annual report)
# ...                                                      ...
# 2020_ALL 41                             10-K (Annual report)
#          42                             10-K (Annual report)
#          44                             10-K (Annual report)
#          45                             10-K (Annual report)
#          46                             10-K (Annual report)
#
#             Filed\n(YYYY-MM-DD) Reporting for\n(YYYY-MM-DD)  \
# 2010_ALL 0           2010-03-01                  2010-01-01
#          1           2010-02-22                  2009-12-31
# ...

# %%
dataframe['Filed\n(YYYY-MM-DD)']
# Out:
# 2010_ALL  0    2010-03-01
#           1    2010-02-22
# 2011_ALL  0    2011-03-01
#           1    2011-03-01
#           2    2011-05-20
#                   ...
# 2020_ALL  41   2020-02-20
#           42   2020-04-29
#           44   2020-03-25
#           45   2020-02-19
#           46   2020-02-20
# Name: Filed\n(YYYY-MM-DD), Length: 2994, dtype: datetime64[ns]

# %%
dataframe_2010 = dataframe[dataframe['Filed\n(YYYY-MM-DD)'].dt.year == 2010]

# %%
dataframe_2010
# Out:
#                                                 Form & File  \
# 2010_ALL 0                       10-K (Annual report) EX-13
#          1  20-F (Annual report - foreign issuer) EX-15.(B)
#
#            Filed\n(YYYY-MM-DD) Reporting for\n(YYYY-MM-DD)  \
# 2010_ALL 0          2010-03-01                  2010-01-01
#          1          2010-02-22                  2009-12-31
#
#                                 Filing entity/person   SIC  \
# 2010_ALL 0                               TELLABS INC  3661
#          1  KONINKLIJKE PHILIPS ELECTRONICS NV (PHG)  3600
#
#            CIK\n(full 10 digit)         Located Incorporated  \
# 2010_ALL 0               317771  Naperville, IL     Delaware
#          1               313216   Amsterdam, P7  Netherlands
#
#                                           Conflict mineral(s) *adverse*  \
# 2010_ALL 0  Supply Chain\n\nExpect excellence\n\nthroughou...  00:00:00
#          1  \t \t‘Conflict’ minerals: issues further down ...  00:00:00
#
# ...
