# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans

# read the data from CSV file
# data = pd.read_csv('/Users/mohamedgani/Downloads/Exhibits/combined_file.csv')
data = pd.read_csv('/Users/mohamedgani/Downloads/output_final_htm_file.csv')
data = data.dropna()

# %%
data
# Out:
#            id                                                url  \
# 1           0  https://www.sec.gov/Archives/edgar/data/127501...
# 2           0  https://www.sec.gov/Archives/edgar/data/127501...
# 3           0  https://www.sec.gov/Archives/edgar/data/127501...
# 4           0  https://www.sec.gov/Archives/edgar/data/127501...
# 5           0  https://www.sec.gov/Archives/edgar/data/127501...
# ...       ...                                                ...
# 134341  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134342  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134344  11267  https://www.sec.gov/Archives/edgar/data/107820...
# 134345  11267  https://www.sec.gov/Archives/edgar/data/107820...
# 134346  11267  https://www.sec.gov/Archives/edgar/data/107820...
#
#                                                   b title  \
# 1                              Ultra Clean Holdings, Inc.
# 2                                Conflict Minerals Report
# 3                    For The Year Ended December 31, 2020
# 4       Requirements for this Report on Conflict Minerals
# 5                                        Company Overview
# ...                                                   ...
# 134341                           Results of Due Diligence
# 134342     Cautionary Note on Forward-Looking\nStatements
# 134344                                       EXHIBIT 1.02
# 134345         Conflict Minerals Report of Nautilus, Inc.
# 134346  in Accordance with Rule 13p-1 under the Securi...
#
#                                      corresponding p text
# 1                               Conflict Minerals Report
# 2       For The Year Ended December 31, 2020 The follo...
# 3       The following should be read in conjunction wi...
# 4       This report for the year ended December 31, 20...
# 5       Ultra Clean Holdings, Inc. (the “Company”) has...
# ...                                                   ...
# 134341                 Identified Smelters and Refiners.
# 134342  Identified Countries of Origin Efforts to Dete...
# 134344        Conflict Minerals Report of Nautilus, Inc.
# 134345  in Accordance with Rule 13p-1 under the Securi...
# 134346  We determined that certain of our products man...
#
# [72094 rows x 4 columns]
#            id                                                url  \
# 1           0  https://www.sec.gov/Archives/edgar/data/127501...
# 2           0  https://www.sec.gov/Archives/edgar/data/127501...
# 3           0  https://www.sec.gov/Archives/edgar/data/127501...
# 4           0  https://www.sec.gov/Archives/edgar/data/127501...
# 5           0  https://www.sec.gov/Archives/edgar/data/127501...
# ...       ...                                                ...
# 134341  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134342  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134344  11267  https://www.sec.gov/Archives/edgar/data/107820...
# 134345  11267  https://www.sec.gov/Archives/edgar/data/107820...
# 134346  11267  https://www.sec.gov/Archives/edgar/data/107820...
#
#                                                   b title  \
# 1                              Ultra Clean Holdings, Inc.
# 2                                Conflict Minerals Report
# 3                    For The Year Ended December 31, 2020
# 4       Requirements for this Report on Conflict Minerals
# 5                                        Company Overview
# ...                                                   ...
# 134341                           Results of Due Diligence
# 134342     Cautionary Note on Forward-Looking\nStatements
# 134344                                       EXHIBIT 1.02
# 134345         Conflict Minerals Report of Nautilus, Inc.
# 134346  in Accordance with Rule 13p-1 under the Securi...
#
#                                      corresponding p text
# 1                               Conflict Minerals Report
# 2       For The Year Ended December 31, 2020 The follo...
# 3       The following should be read in conjunction wi...
# 4       This report for the year ended December 31, 20...
# 5       Ultra Clean Holdings, Inc. (the “Company”) has...
# ...                                                   ...
# 134341                 Identified Smelters and Refiners.
# 134342  Identified Countries of Origin Efforts to Dete...
# 134344        Conflict Minerals Report of Nautilus, Inc.
# 134345  in Accordance with Rule 13p-1 under the Securi...
# 134346  We determined that certain of our products man...
#
# [72094 rows x 4 columns]

# %%
# extract the document titles
titles = data['b title']

# create a bag-of-words representation of the documents
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(titles)

# perform K-means clustering
kmeans = KMeans(n_clusters=9, random_state=0).fit(X)

# add the cluster labels to the data frame
data['cluster'] = kmeans.labels_

# %%
# Set the display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
data

# %%
# get the list of words in the vocabulary
words = vectorizer.get_feature_names()

# get the centroid of each cluster
centroids = kmeans.cluster_centers_

# print the top words for each cluster
for i in range(kmeans.n_clusters):
    print(f"Cluster {i} words:", end='')
    for ind in centroids[i].argsort()[-10:]:
        print(f" {words[ind]}", end='')
    print()
# Out:
# Cluster 0 words: mine the information location and inquiry reasonable country origin of
# Cluster 1 words: company our to inc the policy of report minerals conflict
# Cluster 2 words: on supply process chain design results measures of due diligence
# Cluster 3 words: 2014 to from 31 december january reporting the for period
# Cluster 4 words: risks step risk assess identify in the and chain supply
# Cluster 5 words: 2020 2015 2014 2013 for the ended 31 december year
# Cluster 6 words: inc tin overview and 01 company of smelter gold exhibit
# Cluster 7 words: taken design steps strategy risks respond mitigate risk and to
# Cluster 8 words: out diligence due audit independent third party of supply chain
# Cluster 0 words: mine the information location and inquiry reasonable country origin of
# Cluster 1 words: company our to inc the policy of report minerals conflict
# Cluster 2 words: on supply process chain design results measures of due diligence
# Cluster 3 words: 2014 to from 31 december january reporting the for period
# Cluster 4 words: risks step risk assess identify in the and chain supply
# Cluster 5 words: 2020 2015 2014 2013 for the ended 31 december year
# Cluster 6 words: inc tin overview and 01 company of smelter gold exhibit
# Cluster 7 words: taken design steps strategy risks respond mitigate risk and to
# Cluster 8 words: out diligence due audit independent third party of supply chain
# /Users/mohamedgani/.local/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /Users/mohamedgani/.local/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Keep only rows that have the value of 5 in the column 'my_column'
data = data.loc[data['cluster'] == 2]
# Replace all other values with NaN
data['cluster'] = data['cluster'].mask(data['cluster'] != 2, other=pd.np.nan)
# Out:
# /var/folders/_y/wz6g1cm11wq6rbwdxh8k39g40000gn/T/ipykernel_39934/3326307898.py:4: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   data['cluster'] = data['cluster'].mask(data['cluster'] != 2, other=pd.np.nan)
# /var/folders/_y/wz6g1cm11wq6rbwdxh8k39g40000gn/T/ipykernel_39934/3326307898.py:4: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   data['cluster'] = data['cluster'].mask(data['cluster'] != 2, other=pd.np.nan)
# /var/folders/_y/wz6g1cm11wq6rbwdxh8k39g40000gn/T/ipykernel_39934/3326307898.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['cluster'] = data['cluster'].mask(data['cluster'] != 2, other=pd.np.nan)
# /var/folders/_y/wz6g1cm11wq6rbwdxh8k39g40000gn/T/ipykernel_39934/3326307898.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['cluster'] = data['cluster'].mask(data['cluster'] != 2, other=pd.np.nan)

# %%
data = data.dropna()
data
# Out:
#            id                                                url  \
# 7           0  https://www.sec.gov/Archives/edgar/data/127501...
# 8           0  https://www.sec.gov/Archives/edgar/data/127501...
# 9           0  https://www.sec.gov/Archives/edgar/data/127501...
# 29          1  https://www.sec.gov/Archives/edgar/data/320193...
# 36          1  https://www.sec.gov/Archives/edgar/data/320193...
# ...       ...                                                ...
# 134336  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134338  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134339  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134340  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134341  11264  https://www.sec.gov/Archives/edgar/data/704532...
#
#                                                   b title  \
# 7                        Design of Due Diligence Measures
# 8                            Due Diligence Measures Taken
# 9                                   Due Diligence Results
# 29                                 Upstream Due Diligence
# 36      OECD Step 5: Report on Supply Chain Due Diligence
# ...                                                   ...
# 134336                              Due Diligence Process
# 134338                            Design of Due Diligence
# 134339              Description of Due Diligence Measures
# 134340                           Results of Due Diligence
# 134341                           Results of Due Diligence
#
#                                      corresponding p text  cluster
# 7       The Company has established management systems...        2
# 8       The Company first identified suppliers and als...        2
# 9       Through its efforts, the Company received info...        2
# 29      Each year, we analyze incident data provided b...        2
# 36      Apple reports annually on its due diligence re...        2
# ...                                                   ...      ...
# 134336  Due Diligence Process The Company’s supply cha...        2
# 134338  The Company’s due diligence measures have been...        2
# 134339  The\nCompany’s due diligence on the source and...        2
# 134340  Identify and Assess Risk in the Supply Chain I...        2
# 134341                 Identified Smelters and Refiners.         2
#
# [8743 rows x 5 columns]
#            id                                                url  \
# 7           0  https://www.sec.gov/Archives/edgar/data/127501...
# 8           0  https://www.sec.gov/Archives/edgar/data/127501...
# 9           0  https://www.sec.gov/Archives/edgar/data/127501...
# 29          1  https://www.sec.gov/Archives/edgar/data/320193...
# 36          1  https://www.sec.gov/Archives/edgar/data/320193...
# ...       ...                                                ...
# 134336  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134338  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134339  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134340  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134341  11264  https://www.sec.gov/Archives/edgar/data/704532...
#
#                                                   b title  \
# 7                        Design of Due Diligence Measures
# 8                            Due Diligence Measures Taken
# 9                                   Due Diligence Results
# 29                                 Upstream Due Diligence
# 36      OECD Step 5: Report on Supply Chain Due Diligence
# ...                                                   ...
# 134336                              Due Diligence Process
# 134338                            Design of Due Diligence
# 134339              Description of Due Diligence Measures
# 134340                           Results of Due Diligence
# 134341                           Results of Due Diligence
#
#                                      corresponding p text  cluster
# 7       The Company has established management systems...        2
# 8       The Company first identified suppliers and als...        2
# 9       Through its efforts, the Company received info...        2
# 29      Each year, we analyze incident data provided b...        2
# 36      Apple reports annually on its due diligence re...        2
# ...                                                   ...      ...
# 134336  Due Diligence Process The Company’s supply cha...        2
# 134338  The Company’s due diligence measures have been...        2
# 134339  The\nCompany’s due diligence on the source and...        2
# 134340  Identify and Assess Risk in the Supply Chain I...        2
# 134341                 Identified Smelters and Refiners.         2
#
# [8743 rows x 5 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# extract the document titles
titles = data['b title']

# create a bag-of-words representation of the documents
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(titles)

# perform K-means clustering
kmeans = KMeans(n_clusters=3, random_state=0).fit(X)

# add the cluster labels to the data frame
data['cluster_2'] = kmeans.labels_

data
# Out:
#            id                                                url  \
# 7           0  https://www.sec.gov/Archives/edgar/data/127501...
# 8           0  https://www.sec.gov/Archives/edgar/data/127501...
# 9           0  https://www.sec.gov/Archives/edgar/data/127501...
# 29          1  https://www.sec.gov/Archives/edgar/data/320193...
# 36          1  https://www.sec.gov/Archives/edgar/data/320193...
# ...       ...                                                ...
# 134336  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134338  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134339  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134340  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134341  11264  https://www.sec.gov/Archives/edgar/data/704532...
#
#                                                   b title  \
# 7                        Design of Due Diligence Measures
# 8                            Due Diligence Measures Taken
# 9                                   Due Diligence Results
# 29                                 Upstream Due Diligence
# 36      OECD Step 5: Report on Supply Chain Due Diligence
# ...                                                   ...
# 134336                              Due Diligence Process
# 134338                            Design of Due Diligence
# 134339              Description of Due Diligence Measures
# 134340                           Results of Due Diligence
# 134341                           Results of Due Diligence
#
#                                      corresponding p text  cluster  cluster_2
# 7       The Company has established management systems...        2          0
# 8       The Company first identified suppliers and als...        2          1
# 9       Through its efforts, the Company received info...        2          0
# 29      Each year, we analyze incident data provided b...        2          1
# 36      Apple reports annually on its due diligence re...        2          2
# ...                                                   ...      ...        ...
# 134336  Due Diligence Process The Company’s supply cha...        2          1
# 134338  The Company’s due diligence measures have been...        2          0
# 134339  The\nCompany’s due diligence on the source and...        2          1
# 134340  Identify and Assess Risk in the Supply Chain I...        2          0
# 134341                 Identified Smelters and Refiners.         2          0
#
# [8743 rows x 6 columns]
#            id                                                url  \
# 7           0  https://www.sec.gov/Archives/edgar/data/127501...
# 8           0  https://www.sec.gov/Archives/edgar/data/127501...
# 9           0  https://www.sec.gov/Archives/edgar/data/127501...
# 29          1  https://www.sec.gov/Archives/edgar/data/320193...
# 36          1  https://www.sec.gov/Archives/edgar/data/320193...
# ...       ...                                                ...
# 134336  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134338  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134339  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134340  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134341  11264  https://www.sec.gov/Archives/edgar/data/704532...
#
#                                                   b title  \
# 7                        Design of Due Diligence Measures
# 8                            Due Diligence Measures Taken
# 9                                   Due Diligence Results
# 29                                 Upstream Due Diligence
# 36      OECD Step 5: Report on Supply Chain Due Diligence
# ...                                                   ...
# 134336                              Due Diligence Process
# 134338                            Design of Due Diligence
# 134339              Description of Due Diligence Measures
# 134340                           Results of Due Diligence
# 134341                           Results of Due Diligence
#
#                                      corresponding p text  cluster  cluster_2
# 7       The Company has established management systems...        2          0
# 8       The Company first identified suppliers and als...        2          1
# 9       Through its efforts, the Company received info...        2          0
# 29      Each year, we analyze incident data provided b...        2          1
# 36      Apple reports annually on its due diligence re...        2          2
# ...                                                   ...      ...        ...
# 134336  Due Diligence Process The Company’s supply cha...        2          1
# 134338  The Company’s due diligence measures have been...        2          0
# 134339  The\nCompany’s due diligence on the source and...        2          1
# 134340  Identify and Assess Risk in the Supply Chain I...        2          0
# 134341                 Identified Smelters and Refiners.         2          0
#
# [8743 rows x 6 columns]

# %%
# get the list of words in the vocabulary
words = vectorizer.get_feature_names()

# get the centroid of each cluster
centroids = kmeans.cluster_centers_

# print the top words for each cluster
for i in range(kmeans.n_clusters):
    print(f"Cluster {i} words:", end='')
    for ind in centroids[i].argsort()[-10:]:
        print(f" {words[ind]}", end='')
    print()
# Out:
# Cluster 0 words: process framework and our measures design due diligence of results
# Cluster 1 words: the of and future program performed process measures diligence due
# Cluster 2 words: reporting oecd diligence due annually step chain report on supply
# /Users/mohamedgani/.local/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Cluster 0 words: process framework and our measures design due diligence of results
# Cluster 1 words: the of and future program performed process measures diligence due
# Cluster 2 words: reporting oecd diligence due annually step chain report on supply
# /Users/mohamedgani/.local/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
import nltk
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
# Preprocess data
def preprocess_text(text):
    # Remove punctuation and double quotes
    text = text.translate(str.maketrans('', '', string.punctuation.replace('"', '')))
    
    # Convert text to lowercase
    text = text.lower()
    
    # Tokenize the text into words
    words = nltk.word_tokenize(text)
    
    # Remove stop words
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    
    # Lemmatize the words
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    
    # Join the words back into a string
    preprocessed_text = ' '.join(words)
    return preprocessed_text

data['corresponding p new text'] = data['corresponding p text'].apply(preprocess_text)

data
# Out:
#            id                                                url  \
# 7           0  https://www.sec.gov/Archives/edgar/data/127501...
# 8           0  https://www.sec.gov/Archives/edgar/data/127501...
# 9           0  https://www.sec.gov/Archives/edgar/data/127501...
# 29          1  https://www.sec.gov/Archives/edgar/data/320193...
# 36          1  https://www.sec.gov/Archives/edgar/data/320193...
# ...       ...                                                ...
# 134336  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134338  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134339  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134340  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134341  11264  https://www.sec.gov/Archives/edgar/data/704532...
#
#                                                   b title  \
# 7                        Design of Due Diligence Measures
# 8                            Due Diligence Measures Taken
# 9                                   Due Diligence Results
# 29                                 Upstream Due Diligence
# 36      OECD Step 5: Report on Supply Chain Due Diligence
# ...                                                   ...
# 134336                              Due Diligence Process
# 134338                            Design of Due Diligence
# 134339              Description of Due Diligence Measures
# 134340                           Results of Due Diligence
# 134341                           Results of Due Diligence
#
#                                      corresponding p text  cluster  cluster_2  \
# 7       The Company has established management systems...        2          0
# 8       The Company first identified suppliers and als...        2          1
# 9       Through its efforts, the Company received info...        2          0
# 29      Each year, we analyze incident data provided b...        2          1
# 36      Apple reports annually on its due diligence re...        2          2
# ...                                                   ...      ...        ...
# 134336  Due Diligence Process The Company’s supply cha...        2          1
# 134338  The Company’s due diligence measures have been...        2          0
# 134339  The\nCompany’s due diligence on the source and...        2          1
# 134340  Identify and Assess Risk in the Supply Chain I...        2          0
# 134341                 Identified Smelters and Refiners.         2          0
#
#                                  corresponding p new text
# 7       company established management system due dili...
# 8       company first identified supplier also analyze...
# 9       effort company received information 26 supplie...
# 29      year analyze incident data provided itsci rcs ...
# 36      apple report annually due diligence requiremen...
# ...                                                   ...
# 134336  due diligence process company ’ supply chain r...
# 134338  company ’ due diligence measure designed confo...
# 134339  company ’ due diligence source chain custody c...
# 134340  identify ass risk supply chain identification ...
# 134341                         identified smelter refiner
#
# [8743 rows x 7 columns]
#            id                                                url  \
# 7           0  https://www.sec.gov/Archives/edgar/data/127501...
# 8           0  https://www.sec.gov/Archives/edgar/data/127501...
# 9           0  https://www.sec.gov/Archives/edgar/data/127501...
# 29          1  https://www.sec.gov/Archives/edgar/data/320193...
# 36          1  https://www.sec.gov/Archives/edgar/data/320193...
# ...       ...                                                ...
# 134336  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134338  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134339  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134340  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134341  11264  https://www.sec.gov/Archives/edgar/data/704532...
#
#                                                   b title  \
# 7                        Design of Due Diligence Measures
# 8                            Due Diligence Measures Taken
# 9                                   Due Diligence Results
# 29                                 Upstream Due Diligence
# 36      OECD Step 5: Report on Supply Chain Due Diligence
# ...                                                   ...
# 134336                              Due Diligence Process
# 134338                            Design of Due Diligence
# 134339              Description of Due Diligence Measures
# 134340                           Results of Due Diligence
# 134341                           Results of Due Diligence
#
#                                      corresponding p text  cluster  cluster_2  \
# 7       The Company has established management systems...        2          0
# 8       The Company first identified suppliers and als...        2          1
# 9       Through its efforts, the Company received info...        2          0
# 29      Each year, we analyze incident data provided b...        2          1
# 36      Apple reports annually on its due diligence re...        2          2
# ...                                                   ...      ...        ...
# 134336  Due Diligence Process The Company’s supply cha...        2          1
# 134338  The Company’s due diligence measures have been...        2          0
# 134339  The\nCompany’s due diligence on the source and...        2          1
# 134340  Identify and Assess Risk in the Supply Chain I...        2          0
# 134341                 Identified Smelters and Refiners.         2          0
#
#                                  corresponding p new text
# 7       company established management system due dili...
# 8       company first identified supplier also analyze...
# 9       effort company received information 26 supplie...
# 29      year analyze incident data provided itsci rcs ...
# 36      apple report annually due diligence requiremen...
# ...                                                   ...
# 134336  due diligence process company ’ supply chain r...
# 134338  company ’ due diligence measure designed confo...
# 134339  company ’ due diligence source chain custody c...
# 134340  identify ass risk supply chain identification ...
# 134341                         identified smelter refiner
#
# [8743 rows x 7 columns]

# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Download the VADER lexicon if necessary
nltk.download('vader_lexicon')

# Select the rows where cluster_2 is 0
cluster_2_0 = data[data['cluster_2'] == 0]

# Initialize the VADER sentiment analysis model
sia = SentimentIntensityAnalyzer()

# Define a function to calculate the polarity scores for each review
def get_polarity_scores(review):
    # Calculate the polarity scores using the VADER model
    sentiment_scores = sia.polarity_scores(review)
    
    # Extract the positive, negative, and neutral scores
    pos_score = sentiment_scores['pos']
    neg_score = sentiment_scores['neg']
    neu_score = sentiment_scores['neu']
    
    # Extract the compound polarity score
    polarity_score = sentiment_scores['compound']
    
    # Return the scores as a dictionary
    return {'pos_score': pos_score, 'neg_score': neg_score, 'neu_score': neu_score, 'polarity_score': polarity_score}

# Apply the function to the p_text column of the DataFrame to calculate the polarity scores for each review
polarity_scores_df = cluster_2_0['corresponding p new text'].apply(get_polarity_scores).apply(pd.Series)

# Merge the polarity scores DataFrame with the original DataFrame
cluster_2_0 = pd.concat([cluster_2_0, polarity_scores_df], axis=1)

# Define a function to categorize the polarity scores as positive, negative, or neutral
def get_sentiment_label(row):
    pos_score = row['pos_score']
    neg_score = row['neg_score']
    if pos_score > neg_score:
        return 'positive'
    elif pos_score < neg_score:
        return 'negative'
    else:
        return 'neutral'

# Apply the function to the polarity scores DataFrame to categorize the polarity scores
cluster_2_0['sentiment_label'] = polarity_scores_df.apply(get_sentiment_label, axis=1)
cluster_2_0
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/mohamedgani/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/mohamedgani/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#            id                                                url  \
# 7           0  https://www.sec.gov/Archives/edgar/data/127501...
# 9           0  https://www.sec.gov/Archives/edgar/data/127501...
# 123         8  https://www.sec.gov/Archives/edgar/data/183563...
# 194        18  https://www.sec.gov/Archives/edgar/data/177417...
# 305        38  https://www.sec.gov/Archives/edgar/data/159195...
# ...       ...                                                ...
# 134217  11246  https://www.sec.gov/Archives/edgar/data/129010...
# 134321  11258  https://www.sec.gov/Archives/edgar/data/109158...
# 134338  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134340  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134341  11264  https://www.sec.gov/Archives/edgar/data/704532...
#
#                                                   b title  \
# 7                        Design of Due Diligence Measures
# 9                                   Due Diligence Results
# 123                                  Due Diligence Design
# 194                          3.\nResults of Due Diligence
# 305                                 Due Diligence Results
# ...                                                   ...
# 134217  Results of Source and Chain of Custody Due Dil...
# 134321                Section 3: Results of due diligence
# 134338                            Design of Due Diligence
# 134340                           Results of Due Diligence
# 134341                           Results of Due Diligence
#
#                                      corresponding p text  cluster  cluster_2  \
# 7       The Company has established management systems...        2          0
# 9       Through its efforts, the Company received info...        2          0
# 123                           Co-operation OECD Guidance         2          0
# 194     As\na downstream purchaser of potential confli...        2          0
# 305     The Company does not have any reason to believ...        2          0
# ...                                                   ...      ...        ...
# 134217  Of the entities we were able to confirm as sme...        2          0
# 134321  Certain of our suppliers indicated in their su...        2          0
# 134338  The Company’s due diligence measures have been...        2          0
# 134340  Identify and Assess Risk in the Supply Chain I...        2          0
# 134341                 Identified Smelters and Refiners.         2          0
#
#                                  corresponding p new text  pos_score  \
# 7       company established management system due dili...      0.135
# 9       effort company received information 26 supplie...      0.053
# 123                             cooperation oecd guidance      0.000
# 194     downstream purchaser potential conflict minera...      0.028
# 305     company reason believe inscope product conflic...      0.119
# ...                                                   ...        ...
# 134217  entity able confirm smelter refiner independen...      0.105
# 134321  certain supplier indicated survey response sou...      0.104
# 134338  company ’ due diligence measure designed confo...      0.138
# 134340  identify ass risk supply chain identification ...      0.158
# 134341                         identified smelter refiner      0.000
#
#         neg_score  neu_score  polarity_score sentiment_label
# 7           0.064      0.801          0.9786        positive
# 9           0.036      0.911          0.4019        positive
# 123         0.000      1.000          0.0000         neutral
# 194         0.117      0.856         -0.9786        negative
# 305         0.162      0.718         -0.5719        negative
# ...           ...        ...             ...             ...
# 134217      0.026      0.869          0.9786        positive
# 134321      0.152      0.744         -0.5994        negative
# 134338      0.044      0.818          0.8402        positive
# 134340      0.072      0.770          0.9953        positive
# 134341      0.000      1.000          0.0000         neutral
#
# [2093 rows x 12 columns]
#            id                                                url  \
# 7           0  https://www.sec.gov/Archives/edgar/data/127501...
# 9           0  https://www.sec.gov/Archives/edgar/data/127501...
# 123         8  https://www.sec.gov/Archives/edgar/data/183563...
# 194        18  https://www.sec.gov/Archives/edgar/data/177417...
# 305        38  https://www.sec.gov/Archives/edgar/data/159195...
# ...       ...                                                ...
# 134217  11246  https://www.sec.gov/Archives/edgar/data/129010...
# 134321  11258  https://www.sec.gov/Archives/edgar/data/109158...
# 134338  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134340  11264  https://www.sec.gov/Archives/edgar/data/704532...
# 134341  11264  https://www.sec.gov/Archives/edgar/data/704532...
#
#                                                   b title  \
# 7                        Design of Due Diligence Measures
# 9                                   Due Diligence Results
# 123                                  Due Diligence Design
# 194                          3.\nResults of Due Diligence
# 305                                 Due Diligence Results
# ...                                                   ...
# 134217  Results of Source and Chain of Custody Due Dil...
# 134321                Section 3: Results of due diligence
# 134338                            Design of Due Diligence
# 134340                           Results of Due Diligence
# 134341                           Results of Due Diligence
#
#                                      corresponding p text  cluster  cluster_2  \
# 7       The Company has established management systems...        2          0
# 9       Through its efforts, the Company received info...        2          0
# 123                           Co-operation OECD Guidance         2          0
# 194     As\na downstream purchaser of potential confli...        2          0
# 305     The Company does not have any reason to believ...        2          0
# ...                                                   ...      ...        ...
# 134217  Of the entities we were able to confirm as sme...        2          0
# 134321  Certain of our suppliers indicated in their su...        2          0
# 134338  The Company’s due diligence measures have been...        2          0
# 134340  Identify and Assess Risk in the Supply Chain I...        2          0
# 134341                 Identified Smelters and Refiners.         2          0
#
#                                  corresponding p new text  pos_score  \
# 7       company established management system due dili...      0.135
# 9       effort company received information 26 supplie...      0.053
# 123                             cooperation oecd guidance      0.000
# 194     downstream purchaser potential conflict minera...      0.028
# 305     company reason believe inscope product conflic...      0.119
# ...                                                   ...        ...
# 134217  entity able confirm smelter refiner independen...      0.105
# 134321  certain supplier indicated survey response sou...      0.104
# 134338  company ’ due diligence measure designed confo...      0.138
# 134340  identify ass risk supply chain identification ...      0.158
# 134341                         identified smelter refiner      0.000
#
#         neg_score  neu_score  polarity_score sentiment_label
# 7           0.064      0.801          0.9786        positive
# 9           0.036      0.911          0.4019        positive
# 123         0.000      1.000          0.0000         neutral
# 194         0.117      0.856         -0.9786        negative
# 305         0.162      0.718         -0.5719        negative
# ...           ...        ...             ...             ...
# 134217      0.026      0.869          0.9786        positive
# 134321      0.152      0.744         -0.5994        negative
# 134338      0.044      0.818          0.8402        positive
# 134340      0.072      0.770          0.9953        positive
# 134341      0.000      1.000          0.0000         neutral
#
# [2093 rows x 12 columns]

# %%
import csv
cluster_2_0.to_csv('final_sentiment_score_with_all_clusters.csv', quotechar='"', quoting=csv.QUOTE_ALL, index=False)

# %%
pip install nbconvert
